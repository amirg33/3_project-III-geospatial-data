# %%
# Importing necessary modules from different files
from src import visualization, companies_gaming, foursquare

# %%
# Fetching and storing the top three cities with the most gaming companies.
# This data is used to understand where the gaming industry is thriving the most.
df_companies = companies_gaming.find_top_3_gaming_cities()

# Retrieving the location data (latitude, longitude, and other details) of gaming companies
# in the top three cities. This data is crucial for mapping and spatial analysis.
df_locations = companies_gaming.top_3_cities_location()

# Generating interactive Folium maps for San Francisco, New York, and London.
# These maps are focused on the gaming companies in these cities and include various markers and features.
city_sf = visualization.city_map_san_francisco_companies()
city_ny = visualization.city_map_new_york_companies()
city_ld = visualization.city_map_london_companies()

# Building a comprehensive map that includes various categories like Starbucks, Bars, Clubs, and Schools.
# This map is useful for visualizing different points of interest in relation to the gaming companies.
map = visualization.build_map()

# Creating dual pie charts to visually compare the distribution of schools, Starbucks, clubs, and bars
# in the top gaming cities. This helps in understanding the urban landscape and amenities in these areas.
charts = visualization.create_dual_pie_charts('Schools', 'Starbucks', 'Club', 'Bar')
