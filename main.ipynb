# %%
from src import visualization, companies_gaming, foursquare

# %%
#In which cities do we find the top gaming companies?
df_companies = companies_gaming.find_top_3_gaming_cities()
df_locations = companies_gaming.top_3_cities_location()
city_sf = visualization.city_map_san_francisco_companies()
city_ny = visualization.city_map_new_york_companies()
city_ld = visualization.city_map_london_companies()

# %%
#df_merged_weighted_score = foursquare.weighted_count_merged_df()

# %%
#df_merged_weighted_score

# %%
visualization.create_dual_pie_charts('Schools', 'Starbucks', 'Club', 'Bar')

# %%
df_companies
# Out:
#             City  Count
# 0  San Francisco     14
# 1       New York     13
# 2         London      7

# %%
df_locations
# Out:
#                Company Name           City                          Street  \
# 7                  Playfish         London          125 Kensington High St
# 10                    Pikum         London                  7 Chalcot Road
# 11              ExitReality         London
# 12                  Vigster         London
# 59  FremantleMedia Ventures       New York             28 East 28th Street
# 1                 Thumbplay       New York                    599 Broadway
# 2                    OMGPOP       New York                            SoHo
# 54               GameGround       New York
# 6                    Boonty       New York              54 Franklin Street
# 14                 AdParlor       New York                  304 Hudson St.
# 53             Crispy Gamer       New York             35 West 36th Street
# 55                   Zemoga       New York             56 West 22nd Street
# 52      Major League Gaming       New York                   3 Park Avenue
# 21       Dada Entertainment       New York             11 West 42nd Street
# 37                CyberArts  San Francisco                    51 Arbor St,
# 33                  GotGame  San Francisco                 1 Bluxome Place
# 0                   Grockit  San Francisco                500 Third Street
# 23                  Lolapps  San Francisco              116 New Montgomery
# 22                   plaYce  San Francisco
# 20                   ngmoco  San Francisco                185 Berry Street
# 16                 AdParlor  San Francisco           33 New Montgomery St.
# 4               Crunchyroll  San Francisco
# 32                   Booyah  San Francisco  139 Townsend Street, 3rd Floor
# 19                 Scavenja  San Francisco                 539 Bryant St.,
#
#      Latitude   Longitude
# 7   51.499109   -0.198480
# 10  51.539778   -0.152998
# 11  51.500152   -0.126236
# 12  51.500152   -0.126236
# 59  40.743945  -73.985542
# 1   40.725435  -73.997395
# 2   40.723384  -74.001704
# 54  40.756054  -73.986951
# 6   40.717248  -74.002662
# 14  40.726241  -74.007327
# 53  40.750597  -73.985273
# 55  40.744697  -73.989947
# 52  40.752672  -73.975930
# 21  40.754300  -73.981847
# 37  37.737609 -122.435399
# 33  37.777720 -122.395785
# 0   37.775196 -122.419204
# 23  37.787092 -122.399972
# 22  37.802040 -122.438231
# 20  37.770510 -122.401581
# 16  37.788660 -122.401406
# 4   37.781265 -122.393229
# 32  37.420728 -122.210341
# 19  37.780134 -122.396744

# %%
city_sf
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a6a426536108ef630d642711fc79e34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a6a426536108ef630d642711fc79e34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a6a426536108ef630d642711fc79e34 = L.map(
#                 &quot;map_8a6a426536108ef630d642711fc79e34&quot;,
#                 {
#                     center: [37.74209539, -122.38918919999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6807324e6fabec5d05cd7a20f65dc27d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a6a426536108ef630d642711fc79e34);
#
#
#             var marker_3645d84fa62d87794cceafa701794dbc = L.marker(
#                 [37.737609, -122.435399],
#                 {}
#             ).addTo(map_8a6a426536108ef630d642711fc79e34);
#
#
#         var popup_e6fa295235ad2c9c8d0c7efc6278693d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33382317982fed2e128f903c16f5cdfc = $(`&lt;div id=&quot;html_33382317982fed2e128f903c16f5cdfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 1&lt;/div&gt;`)[0];
#                 popup_e6fa295235ad2c9c8d0c7efc6278693d.setContent(html_33382317982fed2e128f903c16f5cdfc);
#
#
#
#         marker_3645d84fa62d87794cceafa701794dbc.bindPopup(popup_e6fa295235ad2c9c8d0c7efc6278693d)
#         ;
#
#
#
#
#             var marker_c1c04fcaf0ee390fc34a03edb60a54e8 = L.marker(
#                 [37.78866, -122.401406],
#                 {}
#             ).addTo(map_8a6a426536108ef630d642711fc79e34);
#
#
#         var popup_beeb86b690c41e609934391cc1515529 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01ec9978e97e1d0816f24e8aba4a7044 = $(`&lt;div id=&quot;html_01ec9978e97e1d0816f24e8aba4a7044&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 2&lt;/div&gt;`)[0];
#                 popup_beeb86b690c41e609934391cc1515529.setContent(html_01ec9978e97e1d0816f24e8aba4a7044);
#
#
#
#         marker_c1c04fcaf0ee390fc34a03edb60a54e8.bindPopup(popup_beeb86b690c41e609934391cc1515529)
#         ;
#
#
#
#
#             var marker_ce8a59638efd386c20290bd0460a98ec = L.marker(
#                 [37.7631345, -122.4184025],
#                 {}
#             ).addTo(map_8a6a426536108ef630d642711fc79e34);
#
#
#         var popup_79cd2c1e3ba1b95ea47adfb3bb336c17 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7a507182a4cba41215d86d1aba534b1 = $(`&lt;div id=&quot;html_e7a507182a4cba41215d86d1aba534b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Midpoint&lt;/div&gt;`)[0];
#                 popup_79cd2c1e3ba1b95ea47adfb3bb336c17.setContent(html_e7a507182a4cba41215d86d1aba534b1);
#
#
#
#         marker_ce8a59638efd386c20290bd0460a98ec.bindPopup(popup_79cd2c1e3ba1b95ea47adfb3bb336c17)
#         ;
#
#
#
#
#             var circle_752f400e4c7c272c0999c511205ef245 = L.circle(
#                 [37.7631345, -122.4184025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1706.895520765864, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8a6a426536108ef630d642711fc79e34);
#
#
#             var polygon_9a481c19b56ba2c95a10949a89c32cd3 = L.polygon(
#                 [[37.737609, -122.435399], [37.77772, -122.395785], [37.775196, -122.419204], [37.7870923, -122.3999719], [37.7705096, -122.4015807], [37.78866, -122.401406], [37.781265, -122.393229], [37.780134, -122.396744]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8a6a426536108ef630d642711fc79e34);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfulls

# %%
city_ny
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b42af91c1e40f1203a6adde34f7a3bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b42af91c1e40f1203a6adde34f7a3bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b42af91c1e40f1203a6adde34f7a3bc = L.map(
#                 &quot;map_0b42af91c1e40f1203a6adde34f7a3bc&quot;,
#                 {
#                     center: [40.73945731, -73.99145785],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a00f4359ddff4cb5c98d0bd70f814cd1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b42af91c1e40f1203a6adde34f7a3bc);
#
#
#             var marker_d80376ef94a0ee20a794478adb065bc8 = L.marker(
#                 [40.717248, -74.002662],
#                 {}
#             ).addTo(map_0b42af91c1e40f1203a6adde34f7a3bc);
#
#
#         var popup_d3c0433cb91e9d87ab86ef718b0fabce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_197d4a9e109e29957b0c5f88a7e8ffc2 = $(`&lt;div id=&quot;html_197d4a9e109e29957b0c5f88a7e8ffc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 1&lt;/div&gt;`)[0];
#                 popup_d3c0433cb91e9d87ab86ef718b0fabce.setContent(html_197d4a9e109e29957b0c5f88a7e8ffc2);
#
#
#
#         marker_d80376ef94a0ee20a794478adb065bc8.bindPopup(popup_d3c0433cb91e9d87ab86ef718b0fabce)
#         ;
#
#
#
#
#             var marker_5f1eddb2ed5baf43a5cf00f6af82a8c0 = L.marker(
#                 [40.752672, -73.97593],
#                 {}
#             ).addTo(map_0b42af91c1e40f1203a6adde34f7a3bc);
#
#
#         var popup_e9c8387a739f04faee7b89aa1b05d727 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b45c7bbc72c28d0bf56e1f4dae6096ed = $(`&lt;div id=&quot;html_b45c7bbc72c28d0bf56e1f4dae6096ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 2&lt;/div&gt;`)[0];
#                 popup_e9c8387a739f04faee7b89aa1b05d727.setContent(html_b45c7bbc72c28d0bf56e1f4dae6096ed);
#
#
#
#         marker_5f1eddb2ed5baf43a5cf00f6af82a8c0.bindPopup(popup_e9c8387a739f04faee7b89aa1b05d727)
#         ;
#
#
#
#
#             var marker_379814288b92cf756122ed7e085dc6ae = L.marker(
#                 [40.73496, -73.989296],
#                 {}
#             ).addTo(map_0b42af91c1e40f1203a6adde34f7a3bc);
#
#
#         var popup_a62f504a9236006959816d15d2b40e45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_459aaa621b82754a70457d97306c5a73 = $(`&lt;div id=&quot;html_459aaa621b82754a70457d97306c5a73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Midpoint&lt;/div&gt;`)[0];
#                 popup_a62f504a9236006959816d15d2b40e45.setContent(html_459aaa621b82754a70457d97306c5a73);
#
#
#
#         marker_379814288b92cf756122ed7e085dc6ae.bindPopup(popup_a62f504a9236006959816d15d2b40e45)
#         ;
#
#
#
#
#             var circle_25435ae643c198154407d42a06c34dc7 = L.circle(
#                 [40.73496, -73.989296],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1235.056269321443, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b42af91c1e40f1203a6adde34f7a3bc);
#
#
#             var polygon_40c609d6d5bbeaeabed295c31330fce7 = L.polygon(
#                 [[40.7439449, -73.9855424], [40.725435, -73.997395], [40.723384, -74.001704], [40.756054, -73.986951], [40.717248, -74.002662], [40.7262412, -74.0073271], [40.750597, -73.985273], [40.744697, -73.989947], [40.752672, -73.97593], [40.7543, -73.981847]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b42af91c1e40f1203a6adde34f7a3bc);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallow

# %%
city_ld
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a665c164f01134a102a1fc2f70610127 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a665c164f01134a102a1fc2f70610127&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a665c164f01134a102a1fc2f70610127 = L.map(
#                 &quot;map_a665c164f01134a102a1fc2f70610127&quot;,
#                 {
#                     center: [51.50979785, -0.15098755],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62e6f3794493a879a8be3df4330fab3d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a665c164f01134a102a1fc2f70610127);
#
#
#             var marker_73ea13fdf6729d9227a4313e42a3e202 = L.marker(
#                 [51.4991094, -0.1984802],
#                 {}
#             ).addTo(map_a665c164f01134a102a1fc2f70610127);
#
#
#         var popup_e49ebebe25500ead16b9670e81ea8e14 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de4667df4f3a369f87175b0a989c2f55 = $(`&lt;div id=&quot;html_de4667df4f3a369f87175b0a989c2f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 1&lt;/div&gt;`)[0];
#                 popup_e49ebebe25500ead16b9670e81ea8e14.setContent(html_de4667df4f3a369f87175b0a989c2f55);
#
#
#
#         marker_73ea13fdf6729d9227a4313e42a3e202.bindPopup(popup_e49ebebe25500ead16b9670e81ea8e14)
#         ;
#
#
#
#
#             var marker_1a896027145b3c70b80db1fef10f6419 = L.marker(
#                 [51.500152, -0.126236],
#                 {}
#             ).addTo(map_a665c164f01134a102a1fc2f70610127);
#
#
#         var popup_5b4949df321fb3ece4cb5655d7aa7728 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75ada6a5d2c13baf7fe711c8e4e7d3cc = $(`&lt;div id=&quot;html_75ada6a5d2c13baf7fe711c8e4e7d3cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point 2&lt;/div&gt;`)[0];
#                 popup_5b4949df321fb3ece4cb5655d7aa7728.setContent(html_75ada6a5d2c13baf7fe711c8e4e7d3cc);
#
#
#
#         marker_1a896027145b3c70b80db1fef10f6419.bindPopup(popup_5b4949df321fb3ece4cb5655d7aa7728)
#         ;
#
#
#
#
#             var marker_2da7cee6a077335fc909d80b95de6ce3 = L.marker(
#                 [51.4996307, -0.1623581],
#                 {}
#             ).addTo(map_a665c164f01134a102a1fc2f70610127);
#
#
#         var popup_7a5e87dc562356726487419571fcb4ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39a4a412ab81e2ddd484db0343fb239d = $(`&lt;div id=&quot;html_39a4a412ab81e2ddd484db0343fb239d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Midpoint&lt;/div&gt;`)[0];
#                 popup_7a5e87dc562356726487419571fcb4ff.setContent(html_39a4a412ab81e2ddd484db0343fb239d);
#
#
#
#         marker_2da7cee6a077335fc909d80b95de6ce3.bindPopup(popup_7a5e87dc562356726487419571fcb4ff)
#         ;
#
#
#
#
#             var circle_3dab56aa4f8ec88d6fe395bc24963a5e = L.circle(
#                 [51.4996307, -0.1623581],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2010.7654456842272, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a665c164f01134a102a1fc2f70610127);
#
#
#             var polygon_6ae41da11315b0ed3f22878826930c16 = L.polygon(
#                 [[51.4991094, -0.1984802], [51.539778, -0.152998], [51.500152, -0.126236], [51.500152, -0.126236]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a665c164f01134a102a1fc2f70610127);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
